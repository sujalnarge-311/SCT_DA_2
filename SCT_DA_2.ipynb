# %% [markdown]
# # **SCT_DA_2**

# %% [markdown]
# ## **1. Import Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## **2. Import Data**

# %%
df = pd.read_csv(r'C:\Users\sujal\Downloads\superstore.csv')

# %% [markdown]
# ## **3. Preview Dataset**

# %%
df.head(10)
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
# 5  Office Supplies  Los Angeles  United States   JF-154904      Jeremy Farry
# 6  Office Supplies  Los Angeles  United States   WB-218504     William Brown
# 7  Office Supplies  Los Angeles  United States   JA-159704      Joseph Airdo
# 8  Office Supplies  Los Angeles  United States   SP-209204      Susan Pistek
# 9  Office Supplies  Los Angeles  United States   RL-196154         Rob Lucas
#
#    Discount Market  记录数               Order.Date        Order.ID  ... Sales  \
# ...

# %%
df.shape
# Out:
# (51290, 27)

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', '记录数', 'Order.Date', 'Order.ID', 'Order.Priority',
#        'Product.ID', 'Product.Name', 'Profit', 'Quantity', 'Region', 'Row.ID',
#        'Sales', 'Segment', 'Ship.Date', 'Ship.Mode', 'Shipping.Cost', 'State',
#        'Sub.Category', 'Year', 'Market2', 'weeknum'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Discount      记录数        Profit      Quantity       Row.ID  \
# count  51290.000000  51290.0  51290.000000  51290.000000  51290.00000
# mean       0.142908      1.0     28.610982      3.476545  25645.50000
# std        0.212280      0.0    174.340972      2.278766  14806.29199
# min        0.000000      1.0  -6599.978000      1.000000      1.00000
# 25%        0.000000      1.0      0.000000      2.000000  12823.25000
# 50%        0.000000      1.0      9.240000      3.000000  25645.50000
# 75%        0.200000      1.0     36.810000      5.000000  38467.75000
# max        0.850000      1.0   8399.976000     14.000000  51290.00000
#
#               Sales  Shipping.Cost          Year       weeknum
# count  51290.000000   51290.000000  51290.000000  51290.000000
# mean     246.498440      26.375818   2012.777208     31.287112
# std      487.567175      57.296810      1.098931     14.429795
# min        0.000000       0.002000   2011.000000      1.000000
# ...

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#            Discount      记录数        Profit      Quantity       Row.ID  \
# count  51290.000000  51290.0  51290.000000  51290.000000  51290.00000
# mean       0.142908      1.0     28.610982      3.476545  25645.50000
# std        0.212280      0.0    174.340972      2.278766  14806.29199
# min        0.000000      1.0  -6599.978000      1.000000      1.00000
# 25%        0.000000      1.0      0.000000      2.000000  12823.25000
# 50%        0.000000      1.0      9.240000      3.000000  25645.50000
# 75%        0.200000      1.0     36.810000      5.000000  38467.75000
# max        0.850000      1.0   8399.976000     14.000000  51290.00000
#
#               Sales  Shipping.Cost          Year       weeknum
# count  51290.000000   51290.000000  51290.000000  51290.000000
# mean     246.498440      26.375818   2012.777208     31.287112
# std      487.567175      57.296810      1.098931     14.429795
# min        0.000000       0.002000   2011.000000      1.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(['记录数', 'Market2', 'Customer.ID'], axis=1, inplace=True)

# %%
df.head()
# Out:
#           Category         City        Country     Customer.Name  Discount  \
# 0  Office Supplies  Los Angeles  United States  Lycoris Saunders       0.0
# 1  Office Supplies  Los Angeles  United States     Mark Van Huff       0.0
# 2  Office Supplies  Los Angeles  United States      Chad Sievert       0.0
# 3  Office Supplies  Los Angeles  United States      Chad Sievert       0.0
# 4  Office Supplies  Los Angeles  United States    Arthur Prichep       0.0
#
#   Market               Order.Date        Order.ID Order.Priority  \
# 0     US  2011-01-07 00:00:00.000  CA-2011-130813           High
# 1     US  2011-01-21 00:00:00.000  CA-2011-148614         Medium
# 2     US  2011-08-05 00:00:00.000  CA-2011-118962         Medium
# 3     US  2011-08-05 00:00:00.000  CA-2011-118962         Medium
# 4     US  2011-09-29 00:00:00.000  CA-2011-146969           High
#
#         Product.ID  ... Row.ID  Sales   Segment                Ship.Date  \
# ...

# %%
df.rename(columns={'Sub.Category': 'Sub_Category','Order.Date': 'Order_Date','Ship.Date': 'Ship_Date'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.Name', 'Discount', 'Market',
#        'Order_Date', 'Order.ID', 'Order.Priority', 'Product.ID',
#        'Product.Name', 'Profit', 'Quantity', 'Region', 'Row.ID', 'Sales',
#        'Segment', 'Ship_Date', 'Ship.Mode', 'Shipping.Cost', 'State',
#        'Sub_Category', 'Year', 'weeknum'],
#       dtype='object')

# %%
df.head()
# Out:
#           Category         City        Country     Customer.Name  Discount  \
# 0  Office Supplies  Los Angeles  United States  Lycoris Saunders       0.0
# 1  Office Supplies  Los Angeles  United States     Mark Van Huff       0.0
# 2  Office Supplies  Los Angeles  United States      Chad Sievert       0.0
# 3  Office Supplies  Los Angeles  United States      Chad Sievert       0.0
# 4  Office Supplies  Los Angeles  United States    Arthur Prichep       0.0
#
#   Market               Order_Date        Order.ID Order.Priority  \
# 0     US  2011-01-07 00:00:00.000  CA-2011-130813           High
# 1     US  2011-01-21 00:00:00.000  CA-2011-148614         Medium
# 2     US  2011-08-05 00:00:00.000  CA-2011-118962         Medium
# 3     US  2011-08-05 00:00:00.000  CA-2011-118962         Medium
# 4     US  2011-09-29 00:00:00.000  CA-2011-146969           High
#
#         Product.ID  ... Row.ID  Sales   Segment                Ship_Date  \
# ...

# %% [markdown]
# ## **4.Check Data Types**

# %%
df.dtypes
# Out:
# Category           object
# City               object
# Country            object
# Customer.Name      object
# Discount          float64
# Market             object
# Order_Date         object
# Order.ID           object
# Order.Priority     object
# Product.ID         object
# Product.Name       object
# Profit            float64
# Quantity            int64
# Region             object
# Row.ID              int64
# Sales               int64
# Segment            object
# Ship_Date          object
# Ship.Mode          object
# Shipping.Cost     float64
# State              object
# Sub_Category       object
# Year                int64
# weeknum             int64
# dtype: object

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Ship_Date'] = pd.to_datetime(df['Ship_Date'])

# %%
df['Category'] = df['Category'].astype('category')
df['Segment'] = df['Segment'].astype('category')
df['Region'] = df['Region'].astype('category')
df['Sub_Category'] = df['Sub_Category'].astype('category')
df['Ship.Mode'] = df['Ship.Mode'].astype('category')

# %%
df.dtypes
# Out:
# Category                category
# City                      object
# Country                   object
# Customer.Name             object
# Discount                 float64
# Market                    object
# Order_Date        datetime64[ns]
# Order.ID                  object
# Order.Priority            object
# Product.ID                object
# Product.Name              object
# Profit                   float64
# Quantity                   int64
# Region                  category
# Row.ID                     int64
# Sales                      int64
# Segment                 category
# Ship_Date         datetime64[ns]
# Ship.Mode               category
# Shipping.Cost            float64
# State                     object
# Sub_Category            category
# Year                       int64
# weeknum                    int64
# dtype: object

# %%
df.to_csv('Cleaned_Global_Superstore.csv', index=False)
